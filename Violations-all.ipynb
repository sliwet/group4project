# %%
import datetime
import json
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
nyrestaurants = pd.read_csv("nyrestaurants.csv", encoding="utf-8")
print(len(nyrestaurants))
print(nyrestaurants.dtypes)
nyrestaurants.head()
# Out:
# 398783
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# PHONE                     object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# CUISINE DESCRIPTION       object
# ZIPCODE                    int64
# INSPECTION DATE           object
# dtype: object
# C:\Users\dhava\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       CAMIS                    DBA   BORO BUILDING           STREET  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
#
#         PHONE                                           ACTION VIOLATION CODE  \
# 0  7188924968  Violations were cited in the following area(s).            04L
# 1  7188924968  Violations were cited in the following area(s).            06D
# 2  7188924968  Violations were cited in the following area(s).            06C
# 3  7188924968  Violations were cited in the following area(s).            10F
# 4  7188924968  Violations were cited in the following area(s).            08A
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0  Evidence of mice or live mice present in facil...      Critical   10.0
# 1  Food contact surface not properly washed, rins...      Critical    7.0
# 2  Food not protected from potential source of co...      Critical    6.0
# 3  Non-food contact surface improperly constructe...  Not Critical    7.0
# 4  Facility not vermin proof. Harborage or condit...  Not Critical   10.0
#
#   GRADE  GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 0     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
# 1     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 2     A  02/09/2015  08/28/2017  Cycle Inspection / Initial Inspection
# 3     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 4     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
#
#   CUISINE DESCRIPTION  ZIPCODE INSPECTION DATE
# 0              Bakery    10462      2014/04/23
# 1              Bakery    10462      2014/08/26
# 2              Bakery    10462      2016/06/16
# 3              Bakery    10462      2017/01/25
# 4              Bakery    10462             NaN

# %%
foodtype = ["Bakery","Hamburgers","Delicatessen","Ice Cream"," Gelato"," Yogurt"," Ices","Hotdogs","Sandwiches/Salads/Mixed Buffet","Donuts","Bagels/Pretzels","Continental","Pizza","Soul Food","Steak","Pizza/Italian","Cafe/Coffee/Tea","Seafood","Tex-Mex","Bottled beverages"," including water"," sodas"," juices"," etc.","Pancakes/Waffles","Other","Chicken","Barbecue","","Vegetarian","Juice"," Smoothies"," Fruit Salads","Sandwiches","Soups & Sandwiches","Tapas","Salads","Creole","Cajun","Creole/Cajun","Hotdogs/Pretzels","Southwestern","Fruits/Vegetables","Nuts/Confectionary","Soups","Californian","Not Listed/Not Applicable"]
ethnicity = ["Irish","American","Jewish/Kosher","Chinese","Caribbean","Italian","Polish","Latin (Cuban"," Dominican"," Puerto Rican"," South & Central American)","German","French","Mexican","Spanish","Mediterranean","Japanese","Greek","Thai","Indian","Korean","Russian","Ethiopian","Eastern European","Middle Eastern","Egyptian","English","Chinese/Cuban","Asian","Portuguese","Indonesian","Turkish","Moroccan","Hawaiian","Filipino","Brazilian","Vietnamese/Cambodian/Malaysia","Chilean","Afghan","Pakistani","Peruvian","African","Armenian","Bangladeshi","Czech","Iranian","Scandinavian","Polynesian","Australian","Chinese/Japanese"]

cuisinetype = []

for i in range(len(nyrestaurants)):
    if nyrestaurants.iloc[i,15] in ethnicity:
        cuisinetype.append("ethnic")
    else:
        cuisinetype.append("food")
temp = pd.DataFrame({"Cuisine Type": cuisinetype})
nyrestaurants = nyrestaurants.join(temp)
nyrestaurants.head()
# Out:
#       CAMIS                    DBA   BORO BUILDING           STREET  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
#
#         PHONE                                           ACTION VIOLATION CODE  \
# 0  7188924968  Violations were cited in the following area(s).            04L
# 1  7188924968  Violations were cited in the following area(s).            06D
# 2  7188924968  Violations were cited in the following area(s).            06C
# 3  7188924968  Violations were cited in the following area(s).            10F
# 4  7188924968  Violations were cited in the following area(s).            08A
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0  Evidence of mice or live mice present in facil...      Critical   10.0
# 1  Food contact surface not properly washed, rins...      Critical    7.0
# 2  Food not protected from potential source of co...      Critical    6.0
# 3  Non-food contact surface improperly constructe...  Not Critical    7.0
# 4  Facility not vermin proof. Harborage or condit...  Not Critical   10.0
#
#   GRADE  GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 0     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
# 1     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 2     A  02/09/2015  08/28/2017  Cycle Inspection / Initial Inspection
# 3     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 4     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
#
#   CUISINE DESCRIPTION  ZIPCODE INSPECTION DATE Cuisine Type
# 0              Bakery    10462      2014/04/23         food
# 1              Bakery    10462      2014/08/26         food
# 2              Bakery    10462      2016/06/16         food
# 3              Bakery    10462      2017/01/25         food
# 4              Bakery    10462             NaN         food

# %%
violationcodes = nyrestaurants['VIOLATION CODE'].unique()
nviolationcodes = len(violationcodes)
print(nviolationcodes)
violationcodes
# Out:
# 98
# array(['04L', '06D', '06C', '10F', '08A', '04A', '15I', '10B', '04J',
#        '08C', '06A', '04N', '15L', '04H', '06B', '02G', '10E', '10A', nan,
#        '02I', '10H', '09A', '20A', '22C', '16B', '06E', '02B', '06F',
#        '10I', '04M', '10J', '02H', '04D', '04K', '20F', '09C', '09B',
#        '04C', '10D', '05D', '22A', '05F', '16A', '02C', '08B', '02A',
#        '05B', '20E', '04E', '02D', '05H', '20D', '04O', '22B', '18F',
#        '15S', '04B', '10C', '16C', '16E', '16D', '03C', '05C', '03B',
#        '22F', '04G', '15J', '04F', '05A', '03A', '22E', '06G', '05E',
#        '15K', '07A', '03G', '18C', '06I', '18B', '18D', '22G', '10G',
#        '03D', '15T', '04I', '15F', '15E', '20B', '06H', '16F', '15A',
#        '05I', '02F', '02E', '03E', '03F', '02J', '15H'], dtype=object)

# %%
cuisines = nyrestaurants['CUISINE DESCRIPTION'].unique()
ncuisines = len(cuisines)
print(ncuisines)
cuisines
# Out:
# 84
# array(['Bakery', 'Hamburgers', 'Irish', 'American', 'Delicatessen',
#        'Ice Cream, Gelato, Yogurt, Ices', 'Hotdogs', 'Jewish/Kosher',
#        'Chinese', 'Sandwiches/Salads/Mixed Buffet', 'Caribbean', 'Donuts',
#        'Bagels/Pretzels', 'Continental', 'Pizza', 'Soul Food', 'Italian',
#        'Steak', 'Polish',
#        'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#        'German', 'French', 'Pizza/Italian', 'Mexican', 'Spanish',
#        'Cafe/Coffee/Tea', 'Seafood', 'Tex-Mex',
#        'Bottled beverages, including water, sodas, juices, etc.',
#        'Pancakes/Waffles', 'Other', 'Mediterranean', 'Japanese', 'Greek',
#        'Thai', 'Indian', 'Korean', 'Chicken', 'Russian', 'Ethiopian',
#        'Eastern European', 'Barbecue', 'Middle Eastern', 'Egyptian',
#        'English', 'Chinese/Cuban', 'Asian', 'Portuguese', 'Indonesian',
#        'Turkish', 'Moroccan', 'Hawaiian', 'Vegetarian', 'Filipino',
#        'Juice, Smoothies, Fruit Salads', 'Sandwiches', 'Brazilian',
#        'Vietnamese/Cambodian/Malaysia', 'Chilean', 'Soups & Sandwiches',
#        'Afghan', 'Tapas', 'Pakistani', 'Peruvian', 'African', 'Armenian',
#        'Bangladeshi', 'Czech', 'Salads', 'Creole', 'Iranian', 'Cajun',
#        'Scandinavian', 'Polynesian', 'Australian', 'Chinese/Japanese',
#        'Creole/Cajun', 'Hotdogs/Pretzels', 'Southwestern',
#        'Fruits/Vegetables', 'Nuts/Confectionary', 'Soups', 'Californian',
#        'Not Listed/Not Applicable'], dtype=object)

# %%
byfood = nyrestaurants.loc[nyrestaurants["Cuisine Type"] == "food", :]
byfood.head()
# Out:
#       CAMIS                    DBA   BORO BUILDING           STREET  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE
#
#         PHONE                                           ACTION VIOLATION CODE  \
# 0  7188924968  Violations were cited in the following area(s).            04L
# 1  7188924968  Violations were cited in the following area(s).            06D
# 2  7188924968  Violations were cited in the following area(s).            06C
# 3  7188924968  Violations were cited in the following area(s).            10F
# 4  7188924968  Violations were cited in the following area(s).            08A
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0  Evidence of mice or live mice present in facil...      Critical   10.0
# 1  Food contact surface not properly washed, rins...      Critical    7.0
# 2  Food not protected from potential source of co...      Critical    6.0
# 3  Non-food contact surface improperly constructe...  Not Critical    7.0
# 4  Facility not vermin proof. Harborage or condit...  Not Critical   10.0
#
#   GRADE  GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 0     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
# 1     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 2     A  02/09/2015  08/28/2017  Cycle Inspection / Initial Inspection
# 3     A  05/18/2017  08/28/2017  Cycle Inspection / Initial Inspection
# 4     A  02/18/2016  08/28/2017  Cycle Inspection / Initial Inspection
#
#   CUISINE DESCRIPTION  ZIPCODE INSPECTION DATE Cuisine Type
# 0              Bakery    10462      2014/04/23         food
# 1              Bakery    10462      2014/08/26         food
# 2              Bakery    10462      2016/06/16         food
# 3              Bakery    10462      2017/01/25         food
# 4              Bakery    10462             NaN         food

# %%
byethnicity = nyrestaurants.loc[nyrestaurants["Cuisine Type"] == "ethnic", :]
byethnicity.head()
# Out:
#        CAMIS                             DBA       BORO BUILDING  \
# 30  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 31  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 32  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 33  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 34  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
#
#               STREET       PHONE  \
# 30  WEST   57 STREET  2122452912
# 31  WEST   57 STREET  2122452912
# 32  WEST   57 STREET  2122452912
# 33  WEST   57 STREET  2122452912
# 34  WEST   57 STREET  2122452912
#
#                                              ACTION VIOLATION CODE  \
# 30  Violations were cited in the following area(s).            10B
# 31  Violations were cited in the following area(s).            02I
# 32  Violations were cited in the following area(s).            10B
# 33  Violations were cited in the following area(s).            10H
# 34  Violations were cited in the following area(s).            04H
#
#                                 VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 30  Plumbing not properly installed or maintained;...  Not Critical   10.0
# 31  Food prepared from ingredients at ambient temp...      Critical   26.0
# 32  Plumbing not properly installed or maintained;...  Not Critical   26.0
# 33  Proper sanitization not provided for utensil w...  Not Critical   12.0
# 34  Raw, cooked or prepared food is adulterated, c...      Critical   26.0
#
#    GRADE  GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 30     A  05/31/2016  08/28/2017  Cycle Inspection / Initial Inspection
# 31   NaN         NaN  08/28/2017  Cycle Inspection / Initial Inspection
# 32   NaN         NaN  08/28/2017  Cycle Inspection / Initial Inspection
# 33   NaN         NaN  08/28/2017  Cycle Inspection / Initial Inspection
# 34   NaN         NaN  08/28/2017  Cycle Inspection / Initial Inspection
#
#    CUISINE DESCRIPTION  ZIPCODE INSPECTION DATE Cuisine Type
# 30               Irish    10019      2014/05/09       ethnic
# 31               Irish    10019      2015/04/07       ethnic
# 32               Irish    10019      2015/04/08       ethnic
# 33               Irish    10019      2015/04/29       ethnic
# 34               Irish    10019      2015/05/26       ethnic

# %%
# By food type
groupByCuisineRest = byfood.groupby(['CUISINE DESCRIPTION','DBA'])
perRestaurant = pd.DataFrame({'# of violations':groupByCuisineRest['CAMIS'].count()})
print(perRestaurant['# of violations'].sum())
perRestaurant.head()
# Out:
# 131218
#                                              # of violations
# CUISINE DESCRIPTION DBA
# Bagels/Pretzels     A&R HOT BAGELS                         3
#                     ABSOLUTE BAGELS                       15
#                     ACE HOT BAGEL & DELI                  26
#                     ACTS III BAGELS                       16
#                     AMERICAN NEW YORK BAGEL               17

# %%
# By ethnicity
groupByCuisineRest = byethnicity.groupby(['CUISINE DESCRIPTION','DBA'])
perRestaurant = pd.DataFrame({'# of violations':groupByCuisineRest['CAMIS'].count()})
print(perRestaurant['# of violations'].sum())
perRestaurant.head()
# Out:
# 267565
#                                                     # of violations
# CUISINE DESCRIPTION DBA
# Afghan              AFGHAN KEBAB HOUSE                            4
#                     AFGHAN KEBAB HOUSE #1                        11
#                     AFGHAN KEBOB HOUSE                           15
#                     ARIA KABAB                                   14
#                     ARIA KABAB /TARIQ AFGHAN KABAB               23

# %%
# All restaurants
groupByCuisineRest = nyrestaurants.groupby(['CUISINE DESCRIPTION','DBA'])
perRestaurant = pd.DataFrame({'# of violations':groupByCuisineRest['CAMIS'].count()})
print(perRestaurant['# of violations'].sum())
perRestaurant.head()
# Out:
# 398783
#                                                     # of violations
# CUISINE DESCRIPTION DBA
# Afghan              AFGHAN KEBAB HOUSE                            4
#                     AFGHAN KEBAB HOUSE #1                        11
#                     AFGHAN KEBOB HOUSE                           15
#                     ARIA KABAB                                   14
#                     ARIA KABAB /TARIQ AFGHAN KABAB               23

# %%
# By food
groupByCuisine = byfood.groupby(['CUISINE DESCRIPTION'])
perCuisine = pd.DataFrame({'# of violations':groupByCuisine['CAMIS'].count()})
nRestPerCuisine = pd.DataFrame({'# of restaurants':groupByCuisine['CAMIS'].nunique()})
perCuisine['# of restaurants'] = nRestPerCuisine['# of restaurants']
perCuisine["nViol_Rest"] = perCuisine['# of violations'] /perCuisine['# of restaurants']
perCuisine.head()
# Out:
#                                                     # of violations  \
# CUISINE DESCRIPTION
# Bagels/Pretzels                                                2795
# Bakery                                                        11946
# Barbecue                                                        858
# Bottled beverages, including water, sodas, juic...             1147
# Cafe/Coffee/Tea                                               15562
#
#                                                     # of restaurants  \
# CUISINE DESCRIPTION
# Bagels/Pretzels                                                  173
# Bakery                                                           726
# Barbecue                                                          52
# Bottled beverages, including water, sodas, juic...               101
# Cafe/Coffee/Tea                                                 1547
#
#                                                     nViol_Rest
# CUISINE DESCRIPTION
# Bagels/Pretzels                                      16.156069
# Bakery                                               16.454545
# Barbecue                                             16.500000
# Bottled beverages, including water, sodas, juic...   11.356436
# Cafe/Coffee/Tea                                      10.059470

# %%
# By ethnicity
groupByCuisine = byethnicity.groupby(['CUISINE DESCRIPTION'])
perCuisine = pd.DataFrame({'# of violations':groupByCuisine['CAMIS'].count()})
nRestPerCuisine = pd.DataFrame({'# of restaurants':groupByCuisine['CAMIS'].nunique()})
perCuisine['# of restaurants'] = nRestPerCuisine['# of restaurants']
perCuisine["nViol_Rest"] = perCuisine['# of violations'] /perCuisine['# of restaurants']
perCuisine.head()
# Out:
#                      # of violations  # of restaurants  nViol_Rest
# CUISINE DESCRIPTION
# Afghan                           221                16   13.812500
# African                         1426                71   20.084507
# American                       90954              6093   14.927622
# Armenian                         484                36   13.444444
# Asian                           6254               366   17.087432

# %%
# All restaurants
groupByCuisine = nyrestaurants.groupby(['CUISINE DESCRIPTION'])
perCuisine = pd.DataFrame({'# of violations':groupByCuisine['CAMIS'].count()})
nRestPerCuisine = pd.DataFrame({'# of restaurants':groupByCuisine['CAMIS'].nunique()})
perCuisine['# of restaurants'] = nRestPerCuisine['# of restaurants']
perCuisine["nViol_Rest"] = perCuisine['# of violations'] /perCuisine['# of restaurants']
perCuisine.head()
# Out:
#                      # of violations  # of restaurants  nViol_Rest
# CUISINE DESCRIPTION
# Afghan                           221                16   13.812500
# African                         1426                71   20.084507
# American                       90954              6093   14.927622
# Armenian                         484                36   13.444444
# Asian                           6254               366   17.087432

# %%
groupByViolationCode = nyrestaurants.groupby(['VIOLATION CODE'])
dftmp = pd.DataFrame({'VIOLATION DESCRIPTION':groupByViolationCode['VIOLATION DESCRIPTION'].unique()})
desclist =[]
for desc in dftmp['VIOLATION DESCRIPTION']:
    desclist.append(desc[0])
desclist

perViolation = pd.DataFrame({'VIOLATION DESCRIPTION':desclist,'# of violations':groupByViolationCode['CAMIS'].count()})
perViolation = perViolation.sort_values('# of violations', ascending=False)

totalviolations = perViolation['# of violations'].sum()
perViolation['%'] = 100 * perViolation['# of violations'] / totalviolations

print(f"Total violations: {totalviolations}")
perViolation.head(15)
# Out:
# Total violations: 393414
#                                             VIOLATION DESCRIPTION  \
# VIOLATION CODE
# 10F             Non-food contact surface improperly constructe...
# 08A             Facility not vermin proof. Harborage or condit...
# 02G             Cold food item held above 41Âº F (smoked fish ...
# 04L             Evidence of mice or live mice present in facil...
# 06D             Food contact surface not properly washed, rins...
# 06C             Food not protected from potential source of co...
# 10B             Plumbing not properly installed or maintained;...
# 02B                   Hot food item not held at or above 140Âº F.
# 04N             Filth flies or food/refuse/sewage-associated (...
# 04M             Live roaches present in facility's food and/or...
# 04H             Raw, cooked or prepared food is adulterated, c...
# 06E             Sanitized equipment or utensil, including in-u...
# 06F             Wiping cloths soiled or not stored in sanitizi...
# 04A             Food Protection Certificate not held by superv...
# 06A             Personal cleanliness inadequate. Outer garment...
#
#                 # of violations          %
# VIOLATION CODE
# 10F                       55785  14.179719
# 08A                       39992  10.165373
# 02G                       27852   7.079565
# 04L                       27777   7.060501
# 06D                       26115   6.638045
# 06C                       25955   6.597376
# 10B                       22141   5.627914
# 02B                       19650   4.994738
# 04N                       19482   4.952035
# 04M                        9016   2.291733
# 04H                        8968   2.279533
# 06E                        8772   2.229712
# 06F                        7692   1.955192
# 04A                        7337   1.864957
# 06A                        7312   1.858602

# %%
perViolation.to_csv("test.csv",index=False,header=True)
perViolation
# Out:
#                                             VIOLATION DESCRIPTION  \
# VIOLATION CODE
# 10F             Non-food contact surface improperly constructe...
# 08A             Facility not vermin proof. Harborage or condit...
# 02G             Cold food item held above 41Âº F (smoked fish ...
# 04L             Evidence of mice or live mice present in facil...
# 06D             Food contact surface not properly washed, rins...
# 06C             Food not protected from potential source of co...
# 10B             Plumbing not properly installed or maintained;...
# 02B                   Hot food item not held at or above 140Âº F.
# 04N             Filth flies or food/refuse/sewage-associated (...
# 04M             Live roaches present in facility's food and/or...
# 04H             Raw, cooked or prepared food is adulterated, c...
# 06E             Sanitized equipment or utensil, including in-u...
# 06F             Wiping cloths soiled or not stored in sanitizi...
# 04A             Food Protection Certificate not held by superv...
# 06A             Personal cleanliness inadequate. Outer garment...
# 10H             Proper sanitization not provided for utensil w...
# 09C                 Food contact surface not properly maintained.
# 08C             Pesticide use not in accordance with label or ...
# 15L             Smoke free workplace smoking policy inadequate...
# 02H             Food not cooled by an approved method whereby ...
# 10I             Single service item reused, improperly stored,...
# 09B                                  Thawing procedures improper.
# 05D             Hand washing facility not provided in or near ...
# 04C             Food worker does not use proper utensil to eli...
# 22C             Bulb not shielded or shatterproof, in areas wh...
# 16B             The original nutritional fact labels and/or in...
# 04J             Appropriately scaled metal stem-type thermomet...
# 10A             Toilet facility not maintained and provided wi...
# 06B             Tobacco use, eating, or drinking from open con...
# 10E             Accurate thermometer not provided in refrigera...
# ...                                                           ...
# 15K             Operator failed to make good faith effort to i...
# 18D             Failure to comply with an Order of the Board o...
# 05A                Sewage disposal system improper or unapproved.
# 22E               ROP processing equipment not approved by DOHMH.
# 10G             Food service operation occurring in room used ...
# 05B             Harmful, noxious gas or vapor detected. CO ~1 ...
# 15T             Original label for tobacco products sold or of...
# 02D             Precooked potentially hazardous food from comm...
# 07A             Duties of an officer of the Department interfe...
# 22G                                                           NaN
# 04B             Food worker prepares food or handles utensil w...
# 18C             Notice of the Department of Board of Health mu...
# 15E                                                           NaN
# 03D             Canned food product observed swollen, leaking ...
# 03E             Potable water supply inadequate. Water or ice ...
# 06I               Food not labeled in accordance with HACCP plan.
# 03G                Raw food not properly washed prior to serving.
# 18B             Document issued by the Board of Health, Commis...
# 06H             Records and logs not maintained to demonstrate...
# 02F             Meat, fish or molluscan shellfish served raw o...
# 15A                                                           NaN
# 16F             Specific caloric content or range thereof not ...
# 04I                                   Unprotected food re-served.
# 20B             Food allergy information poster not posted in ...
# 03F                   Unpasteurized milk or milk product present.
# 04G             Unprotected potentially hazardous food re-served.
# 02E             Whole frozen poultry or poultry breasts, other...
# 02J             Reduced oxygen packaged (ROP) foods not cooled...
# 05I             Refrigeration used to implement HACCP plan not...
# 15H             Sign prohibiting sale of tobacco products to m...
#
#                 # of violations          %
# VIOLATION CODE
# 10F                       55785  14.179719
# 08A                       39992  10.165373
# 02G                       27852   7.079565
# 04L                       27777   7.060501
# 06D                       26115   6.638045
# 06C                       25955   6.597376
# 10B                       22141   5.627914
# 02B                       19650   4.994738
# 04N                       19482   4.952035
# 04M                        9016   2.291733
# 04H                        8968   2.279533
# 06E                        8772   2.229712
# 06F                        7692   1.955192
# 04A                        7337   1.864957
# 06A                        7312   1.858602
# 10H                        6383   1.622464
# 09C                        4969   1.263046
# 08C                        4839   1.230002
# 15L                        4409   1.120702
# 02H                        4177   1.061731
# 10I                        3879   0.985984
# 09B                        3653   0.928538
# 05D                        3429   0.871601
# 04C                        3163   0.803988
# 22C                        3056   0.776790
# 16B                        3020   0.767639
# 04J                        2926   0.743746
# 10A                        2682   0.681725
# 06B                        2645   0.672320
# 10E                        2634   0.669524
# ...                         ...        ...
# 15K                          89   0.022622
# 18D                          85   0.021606
# 05A                          74   0.018810
# 22E                          71   0.018047
# 10G                          56   0.014234
# 05B                          54   0.013726
# 15T                          51   0.012963
# 02D                          40   0.010167
# 07A                          36   0.009151
# 22G                          33   0.008388
# 04B                          29   0.007371
# 18C                          21   0.005338
# 15E                          20   0.005084
# 03D                          16   0.004067
# 03E                          13   0.003304
# 06I                           9   0.002288
# 03G                           9   0.002288
# 18B                           8   0.002033
# 06H                           7   0.001779
# 02F                           7   0.001779
# 15A                           6   0.001525
# 16F                           6   0.001525
# 04I                           6   0.001525
# 20B                           5   0.001271
# 03F                           4   0.001017
# 04G                           4   0.001017
# 02E                           4   0.001017
# 02J                           3   0.000763
# 05I                           1   0.000254
# 15H                           1   0.000254
#
# [97 rows x 3 columns]

# %%
perViolation = pd.read_csv("perviolation.csv")
perViolation
# Out:
#                   VIOLATION DESCRIPTION  # of violations          %
# 0        Non-food contact surface issue          55785.0  14.179719
# 1             Facility not vermin proof          39992.0  10.165373
# 2         Cold food item handling issue          27852.0   7.079565
# 3                      Evidence of mice          27777.0   7.060501
# 4            Food contact surface issue          26115.0   6.638045
# 5               Food contamination risk          25955.0   6.597376
# 6  Pluming/Ventilation/Draining/Sewage           22141.0   5.627914
# 7           Hot food item handing issue          19650.0   4.994738
# 8                             Fly issue          19482.0   4.952035
# 9                                Others              NaN  32.704733

# %%
groupByBoro = nyrestaurants.groupby(['BORO'])
perBoro = pd.DataFrame({'# of Restaurants':groupByBoro['CAMIS'].nunique()
                        ,'# of violations':groupByBoro['CAMIS'].count()})
perBoro = perBoro.sort_values('# of Restaurants', ascending=False)
perBoro['# of violations per restaurant'] = perBoro['# of violations']/perBoro['# of Restaurants']
perBoro.head(15)
# Out:
#                # of Restaurants  # of violations  \
# BORO
# MANHATTAN                 10168           159099
# BROOKLYN                   6223            99297
# QUEENS                     5742            92175
# BRONX                      2323            34824
# STATEN ISLAND               914            13388
#
#                # of violations per restaurant
# BORO
# MANHATTAN                           15.647030
# BROOKLYN                            15.956452
# QUEENS                              16.052769
# BRONX                               14.990960
# STATEN ISLAND                       14.647702

# %%
# # Labels for the sections of our pie chart
# labels = perViolation["VIOLATION DESCRIPTION"]
# # The values of each section of the pie chart
# sizes = perViolation["%"]
# # The colors of each section of the pie chart
# # colors = ["red", "orange", "lightcoral", "lightskyblue"]
# # # Tells matplotlib to seperate the "Python" section from the others
# explode = (0.2, 0, 0, 0 ,0 ,0 ,0 ,0 ,0 ,0)
# plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=-40)
# # ax1.axis('equal')

# fig = plt.gcf()
# fig.set_size_inches(9,8)
# plt.show

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(aspect="equal"))
recipe = perViolation["VIOLATION DESCRIPTION"]
data = perViolation["%"]
# wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)
explode = (0.2, 0, 0, 0 ,0 ,0,0,0,0,0)
wedges, texts  = plt.pie(data, explode=explode, shadow=True, startangle=-40)
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
         bbox=bbox_props, zorder=0, va="center")
for i, p in enumerate(wedges):
   ang = (p.theta2 - p.theta1)/2. + p.theta1
   y = np.sin(np.deg2rad(ang))
   x = np.cos(np.deg2rad(ang))
   horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
   connectionstyle = "angle,angleA=0,angleB={}".format(ang)
   kw["arrowprops"].update({"connectionstyle": connectionstyle})
   ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
               horizontalalignment=horizontalalignment, **kw)
ax.set_title("Matplotlib bakery: A donut")
plt.show()
